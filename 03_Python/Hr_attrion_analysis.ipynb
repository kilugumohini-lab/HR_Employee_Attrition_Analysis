# %% [markdown]
# # HR Attrition Analysis Project

# %% [markdown]
# # Objective
#
# The objective of this project is to analyze employee attrition data and identify key factors affecting employee turnover such as salary, department, experience, and job satisfaction.

# %% [markdown]
# # Tools & Technologies
#
# • Excel (Data Cleaning)
# • SQL Server (Data Analysis)
# • Python (Data Analysis & Visualization)
# • Power BI (Dashboard)

# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd
import numpy as np
# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_excel(
    r"..\01_Data\2.HR_Attrition_Clean_Data.xlsx.xlsx",
    sheet_name="HR-Employee-Attrition"
)

# %%
df
# Out:
#       EmployeeNumber  Age Attrition              Department  Gender  \
# 0                  1   41       Yes                   Sales  Female
# 1                  2   49        No  Research & Development    Male
# 2                  4   37       Yes  Research & Development    Male
# 3                  5   33        No  Research & Development  Female
# 4                  7   27        No  Research & Development    Male
# ...              ...  ...       ...                     ...     ...
# 1465            2061   36        No  Research & Development    Male
# 1466            2062   39        No  Research & Development    Male
# 1467            2064   27        No  Research & Development    Male
# 1468            2065   49        No                   Sales    Male
# 1469            2068   34        No  Research & Development    Male
#
#       Satisfaction MaritalStatus  Salary  Experience  Attrition_Flag  \
# 0                4        Single    5993           8               1
# 1                2       Married    5130          10               0
# 2                3        Single    2090           7               1
# 3                3       Married    2909           8               0
# 4                2       Married    3468           6               0
# ...            ...           ...     ...         ...             ...
# 1465             4       Married    2571          17               0
# 1466             1       Married    9991           9               0
# 1467             2       Married    6142           6               0
# 1468             2       Married    5390          17               0
# 1469             3       Married    4404           6               0
#
#      Salary_Group Experience_Group Satisfaction_Group
# 0          Medium           Medium               High
# 1          Medium      Experienced                Low
# 2             Low           Medium               High
# 3             Low           Medium               High
# 4          Medium           Medium                Low
# ...           ...              ...                ...
# 1465          Low      Experienced               High
# 1466         High           Medium                Low
# 1467       Medium           Medium                Low
# 1468       Medium      Experienced                Low
# 1469       Medium           Medium               High
#
# [1470 rows x 13 columns]

# %%
# preview data
df.head()
# Out:
#    EmployeeNumber  Age Attrition              Department  Gender  \
# 0               1   41       Yes                   Sales  Female
# 1               2   49        No  Research & Development    Male
# 2               4   37       Yes  Research & Development    Male
# 3               5   33        No  Research & Development  Female
# 4               7   27        No  Research & Development    Male
#
#    Satisfaction MaritalStatus  Salary  Experience  Attrition_Flag  \
# 0             4        Single    5993           8               1
# 1             2       Married    5130          10               0
# 2             3        Single    2090           7               1
# 3             3       Married    2909           8               0
# 4             2       Married    3468           6               0
#
#   Salary_Group Experience_Group Satisfaction_Group
# 0       Medium           Medium               High
# 1       Medium      Experienced                Low
# 2          Low           Medium               High
# 3          Low           Medium               High
# 4       Medium           Medium                Low

# %%
# Shape of data
df.shape
# Out:
# (1470, 13)

# %%
# Column names
df.columns
# Out:
# Index(['EmployeeNumber', 'Age', 'Attrition', 'Department', 'Gender',
#        'Satisfaction', 'MaritalStatus', 'Salary', 'Experience',
#        'Attrition_Flag', 'Salary_Group', 'Experience_Group',
#        'Satisfaction_Group'],
#       dtype='object')

# %%
# Data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeNumber      1470 non-null   int64
#  1   Age                 1470 non-null   int64
#  2   Attrition           1470 non-null   object
#  3   Department          1470 non-null   object
#  4   Gender              1470 non-null   object
#  5   Satisfaction        1470 non-null   int64
#  6   MaritalStatus       1470 non-null   object
#  7   Salary              1470 non-null   int64
#  8   Experience          1470 non-null   int64
#  9   Attrition_Flag      1470 non-null   int64
#  10  Salary_Group        1470 non-null   object
#  11  Experience_Group    1470 non-null   object
#  12  Satisfaction_Group  1470 non-null   object
# dtypes: int64(6), object(7)
# memory usage: 149.4+ KB

# %%
# Missing values
df.isnull().sum()
# Out:
# EmployeeNumber        0
# Age                   0
# Attrition             0
# Department            0
# Gender                0
# Satisfaction          0
# MaritalStatus         0
# Salary                0
# Experience            0
# Attrition_Flag        0
# Salary_Group          0
# Experience_Group      0
# Satisfaction_Group    0
# dtype: int64

# %%
# Attrition_Rate
attrition_rate = df["Attrition_Flag"].mean() * 100
print(f"Attrition Rate: {attrition_rate:.2f}%")
# Out:
# Attrition Rate: 16.12%

# %%
#Attrition Count plot
sns.countplot(x="Attrition", data=df)
plt.title("Attrition Count")
plt.show()

# %%
# Department-Wise Attrition
dept_summary = df.groupby("Department").agg(
    Total_Employees=("Attrition_Flag", "count"),
    Attrition_Rate=("Attrition_Flag", "mean")
)

dept_summary["Attrition_Rate"] = dept_summary["Attrition_Rate"] * 100

print(dept_summary)
# Out:
#                         Total_Employees  Attrition_Rate
# Department
# Human Resources                      63       19.047619
# Research & Development              961       13.839750
# Sales                               446       20.627803

# %%
# Department-Wise Chart
dept_summary.plot(kind="bar")
plt.title("Department-wise Attrition Analysis")
plt.ylabel("Values")
plt.xticks(rotation=45)
plt.show()

# %%
# Salary-wise Attrition
salary_attrition = df.groupby("Salary_Group")["Attrition_Flag"].mean() * 100
print(salary_attrition)
# Out:
# Salary_Group
# High      10.804598
# Low       28.607595
# Medium    12.031250
# Name: Attrition_Flag, dtype: float64

# %%
# Salary-Wise Chart
salary_attrition.plot(kind="bar")
plt.title("Attrition Rate by Salary Group")
plt.ylabel("Attrition %")
plt.xlabel("Salary Group")
plt.xticks(rotation=0)
plt.show()

# %%
# Create Age Group
df["Age_Group"] = pd.cut(
    df["Age"],
    bins=[18, 30, 40, 50, 60],
    labels=["18-30", "30-40", "40-50", "50+"]
)

# %%
#Age-Wise Attrition
age_attrition = df.groupby("Age_Group")["Attrition_Flag"].mean() * 100
# Out:
# C:\Users\parap\AppData\Local\Temp\ipykernel_68956\1383337476.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_attrition = df.groupby("Age_Group")["Attrition_Flag"].mean() * 100

# %%
#Age-Wise Chart
age_attrition.plot(kind="bar")
plt.title("Attrition by Age Group")
plt.ylabel("Attrition %")
plt.show()

# %%
#Experience-Wise Attrition
exp_attrition = df.groupby("Experience_Group")["Attrition_Flag"].mean() * 100

# %%
#Experience-Wise Chart
exp_attrition.plot()
plt.title("Attrition vs Experience")
plt.ylabel("Attrition %")
plt.show()

# %%
#Satisfaction-Wise Attrition
satisfaction_attrition = df.groupby("Satisfaction_Group")["Attrition_Flag"].mean() * 100
print(satisfaction_attrition)
# Out:
# Satisfaction_Group
# High    13.873474
# Low     19.683656
# Name: Attrition_Flag, dtype: float64

# %%
#Satisfaction Pie Chart
satisfaction_attrition.plot(kind="pie", autopct="%1.1f%%")
plt.title("Attrition Share by Satisfaction Level")
plt.show()

# %%
# Salary & Satisfaction Analysis
dept_sat = df.groupby(
    ["Salary_Group", "Satisfaction_Group"]
)["Attrition_Flag"].mean() * 100

# %%
# Salary & Satisfaction Chart
dept_sat.unstack().plot(kind="bar")
plt.title("Attrition by Salary & Satisfaction")
plt.ylabel("Attrition %")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Final Insights
#
# 1. The Sales department shows the highest attrition rate compared to other departments.
#
# 2. Employees in the low salary group are more likely to leave the company.
#
# 3. Younger employees (age group 18–30) have higher attrition rates.
#
# 4. Most employees leave within the first 0–2 years of joining.
#
# 5. Employees with low job satisfaction are more likely to leave.
#
# 6. Salary, satisfaction, and experience are the key factors influencing attrition.

# %% [markdown]
# # Conclusion
#
# Attrition is mainly influenced by salary, department, age, and job role. The company should focus on improving employee satisfaction, especially in high-risk groups, to reduce attrition.
